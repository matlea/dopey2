# %% [markdown]
# # Dopey2 template
#
#
# https://github.com/matlea/dopey2

# %%
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.append("C:\\Users\\bloch-user\\Documents\\Scripts\\dopey2")
import dopey
# Out:
# dopey:
#   dopey.dopey_constants    (version 25.02.21)
#   dopey.dopey_loader       (version 25.10.13)
#   dopey.dopey_plot         (version 25.10.03)
#   dopey.dopey_methods      (version 25.10.18)
#   dopey.dopey_spin         (version 25.10.18)

# %% [markdown]
# <hr>

# %%
data = dopey.load()
